# %% [markdown]
# # Siconos software demo and tutorial
#
# ## Tutorial 2(bis) : a ball bouncing on the ground (event drivent scheme)

# %% [markdown]
# ### Import siconos components
# you may need to set PYTHONPATH or sys.path if siconos python packages are not in standard places.

# %%
import sys
# Update the following line depending on your siconos python installation.
sys.path.append("/usr/local/lib/python2.7/site-packages/")
sys.path.append("/Users/Franck/Library/Python/2.7/lib/python2.7/site-packages/")

# %%
# Main interface to siconos functionnalities : 
# non smooth model description, simulation setup ...
import siconos.kernel as sk    

# "Low-level" nonsmooth solvers
import siconos.numerics as sn

# Python package for scientific computing
import numpy as np

# %% [markdown]
# # Part 1 - NSDS definition
# --> Dynamical systems, constraints, nonsmooth laws ...

# %% [markdown]
# ## The dynamical system

# %% [markdown]
# Consider the following example, a ball bouncing on the ground.
# As described in the figure below, we consider a ball of mass m and radius R, described by 3 generalized coordinates q=(z,x,θ).The ball is subjected to the gravity g. The system is also constituted by a rigid plane, defined by its position with respect to the axis Oz. We assume that the position of the plane is fixed.

# %% [markdown]
# ![BouncingBall](figures/BouncingBall.png "BouncingBall")

# %% [markdown]
# The equation of motion of the ball is given by
#
# $$
#    \dot q = v \\
#    M\dot v = F_{ext}(t) + p\\
#    with \ \ M=\left[\begin{array}{ccc}
#    m &0 &0 \\
#    0 & m & 0 \\
#    0 & 0 & I
#    \end{array}\right] \ \ , \ \ I = \frac{2}{5}mR^2 \ \ and \ \ F_{ext} = \left[\begin{array}{c}
#    -m g \\
#    0  \\
#    0
#    \end{array}\right]
# $$
# with
#
# * M the inertia term, a $n\times{}n$ matrix.
# * p the force due to the non-smooth law, ie the reaction at impact.
# * $F_{ext}(t)  \mathcal R \mapsto \mathcal R^{n}$ the given external force.
#
# we get a second-order Lagrangian linear system defined in Siconos with **LagrangianLinearTIDS**:

# %%
# -- Set dynamical system parameters --
x = [1, 0, 0]    # initial position
v = [0, 0, 0]    # initial velocity
radius = 0.1
m = 1.
g = 9.81
mass = np.eye(3)  # mass matrix
mass[2, 2] = 2. / 5 * radius * radius
# -- Build the dynamical system --
ball = sk.LagrangianLinearTIDS(x, v, mass)
# -- Set external forces --
weight = [-m * g, 0, 0]
ball.setFExtPtr(weight)

# %% [markdown]
# *Remark: when specific functions are needed for external forces, a new class, deriving from LagrangianLinearTIDS can be created*
# *Consider the following example:*

# %%
# definition of a new class of dynamical systems, which inherits from linear lagrangian:
class MyDynamicalSystem(sk.LagrangianLinearTIDS):
    
    def computeFext(self, time):
        print 'compute external forces ...'
        self.setFExtPtr([np.sin(time), np.cos(time), time **2])
        return [np.sin(time), np.cos(time), time **2]

# and create a new instance:
another_ball = MyDynamicalSystem(x, v, mass)
another_ball.computeFext(0.1)
# Out:
# compute external forces ...
# [0.099833416646828155, 0.99500416527802571, 0.010000000000000002]

# %% [markdown]
# To get more details on this (or any other) class of DS, try:
#
# help(classname)

# %%
help(MyDynamicalSystem)
# Out:
# Help on class MyDynamicalSystem in module __main__:
#
# class MyDynamicalSystem(siconos.kernel.LagrangianLinearTIDS)
#  |  Method resolution order:
#  |      MyDynamicalSystem
#  |      siconos.kernel.LagrangianLinearTIDS
#  |      siconos.kernel.LagrangianDS
#  |      siconos.kernel.DynamicalSystem
#  |      __builtin__.object
#  |
#  |  Methods defined here:
#  |
#  |  computeFext(self, time)
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from siconos.kernel.LagrangianLinearTIDS:
#  |
#  |  C(self)
#  |      C(self) -> SP::SiconosMatrix
#  |
#  |      Parameters
#  |      ----------
#  |      self: LagrangianLinearTIDS const *
#  |
#  |  K(self)
#  |      K(self) -> SP::SiconosMatrix
#  |
#  |      Parameters
#  |      ----------
#  |      self: LagrangianLinearTIDS const *
#  |
#  |  __del__ lambda self
#  |
#  |  __disown__(self)
#  |
#  |  __getattr__ lambda self, name
#  |
#  |  __init__(self, *args)
#  |      __init__(self) -> LagrangianLinearTIDS
#  |      __init__(self, q0, v0, M, K, C) -> LagrangianLinearTIDS
#  |
#  |      Parameters
#  |      ----------
#  |      q0: SP::SiconosVector
#  |      v0: SP::SiconosVector
#  |      M: SP::SiconosMatrix
#  |      K: SP::SiconosMatrix
#  |      C: SP::SiconosMatrix
#  |
#  |      __init__(self, q0, v0, M) -> LagrangianLinearTIDS
#  |
#  |      Parameters
#  |      ----------
#  |      q0: SP::SiconosVector
#  |      v0: SP::SiconosVector
#  |      M: SP::SiconosMatrix
#  |
#  |  __repr__ = _swig_repr(self)
#  |
#  |  __setattr__ lambda self, name, value
#  |
#  |  checkDynamicalSystem(self)
#  |      checkDynamicalSystem(self) -> bool
#  |
#  |      Parameters
#  |      ----------
#  |      self: LagrangianLinearTIDS *
#  |
#  |  computeForces(self, *args)
#  |      computeForces(self, t, q, v)
#  |
#  |      Parameters
#  |      ----------
#  |      t: double
#  |      q: SP::SiconosVector
#  |      v: SP::SiconosVector
#  |
#  |      computeForces(self, t)
#  |
#  |      Parameters
#  |      ----------
#  |      t: double
#  |
#  |  computeJacobianRhsx(self, t, isDup=False)
#  |      computeJacobianRhsx(self, t, isDup=False)
#  |
#  |      Parameters
#  |      ----------
#  |      t: double
#  |      isDup: bool
#  |
#  |      computeJacobianRhsx(self, t)
#  |
#  |      Parameters
#  |      ----------
#  |      t: double
#  |
#  |  computeRhs(self, t, isDup=False)
#  |      computeRhs(self, t, isDup=False)
#  |
#  |      Parameters
#  |      ----------
#  |      t: double
#  |      isDup: bool
#  |
#  |      computeRhs(self, t)
#  |
#  |      Parameters
#  |      ----------
#  |      t: double
#  |
#  |  display(self)
#  |      display(self)
#  |
#  |      Parameters
#  |      ----------
#  |      self: LagrangianLinearTIDS const *
#  |
#  |  dsConvergenceIndicator(self)
#  |      dsConvergenceIndicator(self) -> double
#  |
#  |      Parameters
#  |      ----------
#  |      self: LagrangianLinearTIDS *
#  |
#  |  getK(self)
#  |      getK(self) -> SimpleMatrix
#  |
#  |      Parameters
#  |      ----------
#  |      self: LagrangianLinearTIDS const *
#  |
#  |  initRhs(self, t)
#  |      initRhs(self, t)
#  |
#  |      Parameters
#  |      ----------
#  |      t: double
#  |
#  |  initialize(self, t=0, n=1)
#  |      initialize(self, t=0, n=1)
#  |
#  |      Parameters
#  |      ----------
#  |      t: double
#  |      n: unsigned int
#  |
#  |      initialize(self, t=0)
#  |
#  |      Parameters
#  |      ----------
#  |      t: double
#  |
#  |      initialize(self)
#  |
#  |      Parameters
#  |      ----------
#  |      self: LagrangianLinearTIDS *
#  |
#  |  isLinear(self)
#  |      isLinear(self) -> bool
#  |
#  |      Parameters
#  |      ----------
#  |      self: LagrangianLinearTIDS *
#  |
#  |  setCPtr(self, newPtr)
#  |      setCPtr(self, newPtr)
#  |
#  |      Parameters
#  |      ----------
#  |      newPtr: SP::SiconosMatrix
#  |
#  |  setK(self, K)
#  |      setK(self, K)
#  |
#  |      Parameters
#  |      ----------
#  |      K: SiconosMatrix const &
#  |
#  |  setKPtr(self, newPtr)
#  |      setKPtr(self, newPtr)
#  |
#  |      Parameters
#  |      ----------
#  |      newPtr: SP::SiconosMatrix
#  |
#  |  zeroPlugin(self)
#  |      zeroPlugin(self)
#  |
#  |      Parameters
#  |      ----------
#  |      self: LagrangianLinearTIDS *
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from siconos.kernel.LagrangianLinearTIDS:
#  |
#  |  __swig_destroy__ = <built-in function delete_LagrangianLinearTIDS>
#  |      delete_LagrangianLinearTIDS(self)
#  |
#  |      Parameters
#  |      ----------
#  |      self: LagrangianLinearTIDS *
#  |
#  |  __swig_getmethods__ = {'_C': <built-in function LagrangianLinearTIDS__...
#  |
#  |  __swig_setmethods__ = {'_C': <built-in function LagrangianLinearTIDS__...
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from siconos.kernel.LagrangianDS:
#  |
#  |  FGyr(self)
#  |      FGyr(self) -> SP::SiconosVector
#  |
#  |      Parameters
#  |      ----------
#  |      self: LagrangianDS const *
#  |
#  |  acceleration(self)
#  |      acceleration(self) -> SP::SiconosVector
#  |
#  |      Parameters
#  |      ----------
#  |      self: LagrangianDS const *
#  |
#  |  allocateWorkMatrix(self, id, sizeOfRows, sizeOfCols)
#  |      allocateWorkMatrix(self, id, sizeOfRows, sizeOfCols)
#  |
#  |      Parameters
#  |      ----------
#  |      id: LagrangianDS::WorkMatrixNames const &
#  |      sizeOfRows: int
#  |      sizeOfCols: int
#  |
#  |  boundaryConditions(self)
#  |      boundaryConditions(self) -> SP::BoundaryCondition
#  |
#  |      Parameters
#  |      ----------
#  |      self: LagrangianDS *
#  |
#  |  computeFExt(self, time)
#  |      computeFExt(self, time)
#  |
#  |      Parameters
#  |      ----------
#  |      time: double
#  |
#  |  computeFGyr(self, *args)
#  |      computeFGyr(self)
#  |      computeFGyr(self, position, velocity)
#  |
#  |      Parameters
#  |      ----------
#  |      position: SP::SiconosVector
#  |      velocity: SP::SiconosVector
#  |
#  |  computeFInt(self, *args)
#  |      computeFInt(self, time)
#  |
#  |      Parameters
#  |      ----------
#  |      time: double
#  |
#  |      computeFInt(self, time, position, velocity)
#  |
#  |      Parameters
#  |      ----------
#  |      time: double
#  |      position: SP::SiconosVector
#  |      velocity: SP::SiconosVector
#  |
#  |  computeJacobianFGyrq(self, *args)
#  |      computeJacobianFGyrq(self)
#  |      computeJacobianFGyrq(self, position, velocity)
#  |
#  |      Parameters
#  |      ----------
#  |      position: SP::SiconosVector
#  |      velocity: SP::SiconosVector
#  |
#  |  computeJacobianFGyrqDot(self, *args)
#  |      computeJacobianFGyrqDot(self)
#  |      computeJacobianFGyrqDot(self, position, velocity)
#  |
#  |      Parameters
#  |      ----------
#  |      position: SP::SiconosVector
#  |      velocity: SP::SiconosVector
#  |
#  |  computeJacobianFIntq(self, *args)
#  |      computeJacobianFIntq(self, time)
#  |
#  |      Parameters
#  |      ----------
#  |      time: double
#  |
#  |      computeJacobianFIntq(self, time, position, velocity)
#  |
#  |      Parameters
#  |      ----------
#  |      time: double
#  |      position: SP::SiconosVector
#  |      velocity: SP::SiconosVector
#  |
#  |  computeJacobianFIntqDot(self, *args)
#  |      computeJacobianFIntqDot(self, time)
#  |
#  |      Parameters
#  |      ----------
#  |      time: double
#  |
#  |      computeJacobianFIntqDot(self, time, position, velocity)
#  |
#  |      Parameters
#  |      ----------
#  |      time: double
#  |      position: SP::SiconosVector
#  |      velocity: SP::SiconosVector
#  |
#  |  computeJacobianqDotForces(self, time)
#  |      computeJacobianqDotForces(self, time)
#  |
#  |      Parameters
#  |      ----------
#  |      time: double
#  |
#  |  computeJacobianqForces(self, time)
#  |      computeJacobianqForces(self, time)
#  |
#  |      Parameters
#  |      ----------
#  |      time: double
#  |
#  |  computeKineticEnergy(self)
#  |      computeKineticEnergy(self) -> double
#  |
#  |      Parameters
#  |      ----------
#  |      self: LagrangianDS *
#  |
#  |  computeMass(self, *args)
#  |      computeMass(self)
#  |      computeMass(self, position)
#  |
#  |      Parameters
#  |      ----------
#  |      position: SP::SiconosVector
#  |
#  |  computePostImpactVelocity(self)
#  |      computePostImpactVelocity(self)
#  |
#  |      Parameters
#  |      ----------
#  |      self: LagrangianDS *
#  |
#  |  connectToDS(self)
#  |      connectToDS(self)
#  |
#  |      Parameters
#  |      ----------
#  |      self: LagrangianDS *
#  |
#  |  dimension(self)
#  |      dimension(self) -> unsigned int
#  |
#  |      Parameters
#  |      ----------
#  |      self: LagrangianDS const *
#  |
#  |  fExt(self)
#  |      fExt(self) -> SP::SiconosVector
#  |
#  |      Parameters
#  |      ----------
#  |      self: LagrangianDS const *
#  |
#  |  fInt(self)
#  |      fInt(self) -> SP::SiconosVector
#  |
#  |      Parameters
#  |      ----------
#  |      self: LagrangianDS const *
#  |
#  |  forces(self)
#  |      forces(self) -> SP::SiconosVector
#  |
#  |      Parameters
#  |      ----------
#  |      self: LagrangianDS const *
#  |
#  |  forcesMemory(self)
#  |      forcesMemory(self) -> SP::SiconosMemory
#  |
#  |      Parameters
#  |      ----------
#  |      self: LagrangianDS *
#  |
#  |  initForces(self)
#  |      initForces(self)
#  |
#  |      Parameters
#  |      ----------
#  |      self: LagrangianDS *
#  |
#  |  initMemory(self, size)
#  |      initMemory(self, size)
#  |
#  |      Parameters
#  |      ----------
#  |      size: unsigned int
#  |
#  |  initializeNonSmoothInput(self, level)
#  |      initializeNonSmoothInput(self, level)
#  |
#  |      Parameters
#  |      ----------
#  |      level: unsigned int
#  |
#  |  jacobianFGyrq(self)
#  |      jacobianFGyrq(self) -> SP::SiconosMatrix
#  |
#  |      Parameters
#  |      ----------
#  |      self: LagrangianDS const *
#  |
#  |  jacobianFGyrqDot(self)
#  |      jacobianFGyrqDot(self) -> SP::SiconosMatrix
#  |
#  |      Parameters
#  |      ----------
#  |      self: LagrangianDS const *
#  |
#  |  jacobianFIntq(self)
#  |      jacobianFIntq(self) -> SP::SiconosMatrix
#  |
#  |      Parameters
#  |      ----------
#  |      self: LagrangianDS const *
#  |
#  |  jacobianFIntqDot(self)
#  |      jacobianFIntqDot(self) -> SP::SiconosMatrix
#  |
#  |      Parameters
#  |      ----------
#  |      self: LagrangianDS const *
#  |
#  |  jacobianRhsx(self)
#  |      jacobianRhsx(self) -> SP::BlockMatrix
#  |
#  |      Parameters
#  |      ----------
#  |      self: LagrangianDS const *
#  |
#  |  jacobianqDotForces(self)
#  |      jacobianqDotForces(self) -> SP::SiconosMatrix
#  |
#  |      Parameters
#  |      ----------
#  |      self: LagrangianDS const *
#  |
#  |  jacobianqForces(self)
#  |      jacobianqForces(self) -> SP::SiconosMatrix
#  |
#  |      Parameters
#  |      ----------
#  |      self: LagrangianDS const *
#  |
#  |  mass(self)
#  |      mass(self) -> SP::SiconosMatrix
#  |
#  |      Parameters
#  |      ----------
#  |      self: LagrangianDS const *
#  |
#  |  ndof(self)
#  |      ndof(self) -> unsigned int
#  |
#  |      Parameters
#  |      ----------
#  |      self: LagrangianDS const *
#  |
#  |  p(self, level)
#  |      p(self, level) -> SP::SiconosVector
#  |
#  |      Parameters
#  |      ----------
#  |      level: unsigned int
#  |
#  |  pMemory(self, level)
#  |      pMemory(self, level) -> SP::SiconosMemory
#  |
#  |      Parameters
#  |      ----------
#  |      level: unsigned int
#  |
#  |  q(self)
#  |      q(self) -> SP::SiconosVector
#  |
#  |      Parameters
#  |      ----------
#  |      self: LagrangianDS const *
#  |
#  |  q0(self)
#  |      q0(self) -> SP::SiconosVector
#  |
#  |      Parameters
#  |      ----------
#  |      self: LagrangianDS const *
#  |
#  |  qMemory(self)
#  |      qMemory(self) -> SP::SiconosMemory
#  |
#  |      Parameters
#  |      ----------
#  |      self: LagrangianDS const *
#  |
#  |  reactionToBoundaryConditions(self)
#  |      reactionToBoundaryConditions(self) -> SP::SiconosVector
#  |
#  |      Parameters
#  |      ----------
#  |      self: LagrangianDS *
#  |
#  |  resetAllNonSmoothPart(self)
#  |      resetAllNonSmoothPart(self)
#  |
#  |      Parameters
#  |      ----------
#  |      self: LagrangianDS *
#  |
#  |  resetNonSmoothPart(self, level)
#  |      resetNonSmoothPart(self, level)
#  |
#  |      Parameters
#  |      ----------
#  |      level: unsigned int
#  |
#  |  setBoundaryConditions(self, newbd)
#  |      setBoundaryConditions(self, newbd)
#  |
#  |      Parameters
#  |      ----------
#  |      newbd: SP::BoundaryCondition
#  |
#  |  setComputeFExtFunction(self, *args)
#  |      setComputeFExtFunction(self, pluginPath, functionName)
#  |
#  |      Parameters
#  |      ----------
#  |      pluginPath: std::string const &
#  |      functionName: std::string const &
#  |
#  |      setComputeFExtFunction(self, fct)
#  |
#  |      Parameters
#  |      ----------
#  |      fct: VectorFunctionOfTime
#  |
#  |  setComputeFGyrFunction(self, *args)
#  |      setComputeFGyrFunction(self, pluginPath, functionName)
#  |
#  |      Parameters
#  |      ----------
#  |      pluginPath: std::string const &
#  |      functionName: std::string const &
#  |
#  |      setComputeFGyrFunction(self, fct)
#  |
#  |      Parameters
#  |      ----------
#  |      fct: FPtr5
#  |
#  |  setComputeFIntFunction(self, *args)
#  |      setComputeFIntFunction(self, pluginPath, functionName)
#  |
#  |      Parameters
#  |      ----------
#  |      pluginPath: std::string const &
#  |      functionName: std::string const &
#  |
#  |      setComputeFIntFunction(self, fct)
#  |
#  |      Parameters
#  |      ----------
#  |      fct: FPtr6
#  |
#  |  setComputeJacobianFGyrqDotFunction(self, *args)
#  |      setComputeJacobianFGyrqDotFunction(self, pluginPath, functionName)
#  |
#  |      Parameters
#  |      ----------
#  |      pluginPath: std::string const &
#  |      functionName: std::string const &
#  |
#  |      setComputeJacobianFGyrqDotFunction(self, fct)
#  |
#  |      Parameters
#  |      ----------
#  |      fct: FPtr5
#  |
#  |  setComputeJacobianFGyrqFunction(self, *args)
#  |      setComputeJacobianFGyrqFunction(self, pluginPath, functionName)
#  |
#  |      Parameters
#  |      ----------
#  |      pluginPath: std::string const &
#  |      functionName: std::string const &
#  |
#  |      setComputeJacobianFGyrqFunction(self, fct)
#  |
#  |      Parameters
#  |      ----------
#  |      fct: FPtr5
#  |
#  |  setComputeJacobianFIntqDotFunction(self, *args)
#  |      setComputeJacobianFIntqDotFunction(self, pluginPath, functionName)
#  |
#  |      Parameters
#  |      ----------
#  |      pluginPath: std::string const &
#  |      functionName: std::string const &
#  |
#  |      setComputeJacobianFIntqDotFunction(self, fct)
#  |
#  |      Parameters
#  |      ----------
#  |      fct: FPtr6
#  |
#  |  setComputeJacobianFIntqFunction(self, *args)
#  |      setComputeJacobianFIntqFunction(self, pluginPath, functionName)
#  |
#  |      Parameters
#  |      ----------
#  |      pluginPath: std::string const &
#  |      functionName: std::string const &
#  |
#  |      setComputeJacobianFIntqFunction(self, fct)
#  |
#  |      Parameters
#  |      ----------
#  |      fct: FPtr6
#  |
#  |  setComputeMassFunction(self, *args)
#  |      setComputeMassFunction(self, pluginPath, functionName)
#  |
#  |      Parameters
#  |      ----------
#  |      pluginPath: std::string const &
#  |      functionName: std::string const &
#  |
#  |      setComputeMassFunction(self, fct)
#  |
#  |      Parameters
#  |      ----------
#  |      fct: FPtr7
#  |
#  |  setFExtPtr(self, newPtr)
#  |      setFExtPtr(self, newPtr)
#  |
#  |      Parameters
#  |      ----------
#  |      newPtr: SP::SiconosVector
#  |
#  |  setFGyrPtr(self, newPtr)
#  |      setFGyrPtr(self, newPtr)
#  |
#  |      Parameters
#  |      ----------
#  |      newPtr: SP::SiconosVector
#  |
#  |  setFIntPtr(self, newPtr)
#  |      setFIntPtr(self, newPtr)
#  |
#  |      Parameters
#  |      ----------
#  |      newPtr: SP::SiconosVector
#  |
#  |  setJacobianFGyrqDotPtr(self, newPtr)
#  |      setJacobianFGyrqDotPtr(self, newPtr)
#  |
#  |      Parameters
#  |      ----------
#  |      newPtr: SP::SiconosMatrix
#  |
#  |  setJacobianFGyrqPtr(self, newPtr)
#  |      setJacobianFGyrqPtr(self, newPtr)
#  |
#  |      Parameters
#  |      ----------
#  |      newPtr: SP::SiconosMatrix
#  |
#  |  setJacobianFIntqDotPtr(self, newPtr)
#  |      setJacobianFIntqDotPtr(self, newPtr)
#  |
#  |      Parameters
#  |      ----------
#  |      newPtr: SP::SiconosMatrix
#  |
#  |  setJacobianFIntqPtr(self, newPtr)
#  |      setJacobianFIntqPtr(self, newPtr)
#  |
#  |      Parameters
#  |      ----------
#  |      newPtr: SP::SiconosMatrix
#  |
#  |  setMassPtr(self, newPtr)
#  |      setMassPtr(self, newPtr)
#  |
#  |      Parameters
#  |      ----------
#  |      newPtr: SP::SiconosMatrix
#  |
#  |  setNdof(self, newNdof)
#  |      setNdof(self, newNdof)
#  |
#  |      Parameters
#  |      ----------
#  |      newNdof: unsigned int
#  |
#  |  setP(self, newValue, level)
#  |      setP(self, newValue, level)
#  |
#  |      Parameters
#  |      ----------
#  |      newValue: SiconosVector const &
#  |      level: unsigned int
#  |
#  |  setPPtr(self, newPtr, level)
#  |      setPPtr(self, newPtr, level)
#  |
#  |      Parameters
#  |      ----------
#  |      newPtr: SP::SiconosVector
#  |      level: unsigned int
#  |
#  |  setQ(self, newValue)
#  |      setQ(self, newValue)
#  |
#  |      Parameters
#  |      ----------
#  |      newValue: SiconosVector const &
#  |
#  |  setQ0(self, newValue)
#  |      setQ0(self, newValue)
#  |
#  |      Parameters
#  |      ----------
#  |      newValue: SiconosVector const &
#  |
#  |  setQ0Ptr(self, newPtr)
#  |      setQ0Ptr(self, newPtr)
#  |
#  |      Parameters
#  |      ----------
#  |      newPtr: SP::SiconosVector
#  |
#  |  setQPtr(self, newPtr)
#  |      setQPtr(self, newPtr)
#  |
#  |      Parameters
#  |      ----------
#  |      newPtr: SP::SiconosVector
#  |
#  |  setReactionToBoundaryConditions(self, newrbd)
#  |      setReactionToBoundaryConditions(self, newrbd)
#  |
#  |      Parameters
#  |      ----------
#  |      newrbd: SP::SiconosVector
#  |
#  |  setVelocity(self, newValue)
#  |      setVelocity(self, newValue)
#  |
#  |      Parameters
#  |      ----------
#  |      newValue: SiconosVector const &
#  |
#  |  setVelocity0(self, newValue)
#  |      setVelocity0(self, newValue)
#  |
#  |      Parameters
#  |      ----------
#  |      newValue: SiconosVector const &
#  |
#  |  setVelocity0Ptr(self, newPtr)
#  |      setVelocity0Ptr(self, newPtr)
#  |
#  |      Parameters
#  |      ----------
#  |      newPtr: SP::SiconosVector
#  |
#  |  setVelocityPtr(self, newPtr)
#  |      setVelocityPtr(self, newPtr)
#  |
#  |      Parameters
#  |      ----------
#  |      newPtr: SP::SiconosVector
#  |
#  |  swapInMemory(self)
#  |      swapInMemory(self)
#  |
#  |      Parameters
#  |      ----------
#  |      self: LagrangianDS *
#  |
#  |  velocity(self)
#  |      velocity(self) -> SP::SiconosVector
#  |
#  |      Parameters
#  |      ----------
#  |      self: LagrangianDS const *
#  |
#  |  velocity0(self)
#  |      velocity0(self) -> SP::SiconosVector
#  |
#  |      Parameters
#  |      ----------
#  |      self: LagrangianDS const *
#  |
#  |  velocityMemory(self)
#  |      velocityMemory(self) -> SP::SiconosMemory
#  |
#  |      Parameters
#  |      ----------
#  |      self: LagrangianDS const *
#  |
#  |  workMatrix(self, id)
#  |      workMatrix(self, id) -> SP::SimpleMatrix
#  |
#  |      Parameters
#  |      ----------
#  |      id: LagrangianDS::WorkMatrixNames const &
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from siconos.kernel.LagrangianDS:
#  |
#  |  coeffs_denseoutput = 5
#  |
#  |  idMatrix = 4
#  |
#  |  invMass = 0
#  |
#  |  jacobianXBloc10 = 1
#  |
#  |  jacobianXBloc11 = 2
#  |
#  |  sizeWorkMat = 6
#  |
#  |  sizeWorkVec = 1
#  |
#  |  xfree = 0
#  |
#  |  zeroMatrix = 3
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from siconos.kernel.DynamicalSystem:
#  |
#  |  addWorkVector(self, newVal, id)
#  |      addWorkVector(self, newVal, id)
#  |
#  |      Parameters
#  |      ----------
#  |      newVal: SP::SiconosVector
#  |      id: DynamicalSystem::WorkNames const &
#  |
#  |  allocateWorkVector(self, id, size)
#  |      allocateWorkVector(self, id, size)
#  |
#  |      Parameters
#  |      ----------
#  |      id: DynamicalSystem::WorkNames const &
#  |      size: int
#  |
#  |  endStep(self)
#  |      endStep(self)
#  |
#  |      Parameters
#  |      ----------
#  |      self: DynamicalSystem *
#  |
#  |  getPluginG(self)
#  |      getPluginG(self) -> SP::PluggedObject
#  |
#  |      Parameters
#  |      ----------
#  |      self: DynamicalSystem const *
#  |
#  |  getPluginJacGX(self)
#  |      getPluginJacGX(self) -> SP::PluggedObject
#  |
#  |      Parameters
#  |      ----------
#  |      self: DynamicalSystem const *
#  |
#  |  getPluginJacXDotG(self)
#  |      getPluginJacXDotG(self) -> SP::PluggedObject
#  |
#  |      Parameters
#  |      ----------
#  |      self: DynamicalSystem const *
#  |
#  |  getR(self)
#  |      getR(self) -> SiconosVector
#  |
#  |      Parameters
#  |      ----------
#  |      self: DynamicalSystem const *
#  |
#  |  getRhs(self)
#  |      getRhs(self) -> SiconosVector
#  |
#  |      Parameters
#  |      ----------
#  |      self: DynamicalSystem const *
#  |
#  |  getSort(self)
#  |      getSort(self) -> int
#  |
#  |      Parameters
#  |      ----------
#  |      self: DynamicalSystem const *
#  |
#  |  getX0(self)
#  |      getX0(self) -> SiconosVector
#  |
#  |      Parameters
#  |      ----------
#  |      self: DynamicalSystem const *
#  |
#  |  getx(self)
#  |      getx(self) -> SiconosVector
#  |
#  |      Parameters
#  |      ----------
#  |      self: DynamicalSystem const *
#  |
#  |  getz(self)
#  |      getz(self) -> SiconosVector
#  |
#  |      Parameters
#  |      ----------
#  |      self: DynamicalSystem const *
#  |
#  |  initWorkSpace(self, workVector, workMatrices)
#  |      initWorkSpace(self, workVector, workMatrices)
#  |
#  |      Parameters
#  |      ----------
#  |      workVector: VectorOfVectors &
#  |      workMatrices: VectorOfMatrices &
#  |
#  |  n(self)
#  |      n(self) -> unsigned int
#  |
#  |      Parameters
#  |      ----------
#  |      self: DynamicalSystem const *
#  |
#  |  normRef(self)
#  |      normRef(self) -> double
#  |
#  |      Parameters
#  |      ----------
#  |      self: DynamicalSystem const *
#  |
#  |  number(self)
#  |      number(self) -> int
#  |
#  |      Parameters
#  |      ----------
#  |      self: DynamicalSystem const *
#  |
#  |  r(self)
#  |      r(self) -> SP::SiconosVector
#  |
#  |      Parameters
#  |      ----------
#  |      self: DynamicalSystem const *
#  |
#  |  rhs(self)
#  |      rhs(self) -> SP::SiconosVector
#  |
#  |      Parameters
#  |      ----------
#  |      self: DynamicalSystem const *
#  |
#  |  setComputeJacobianDotXGFunction(self, *args)
#  |      setComputeJacobianDotXGFunction(self, pluginPath, functionName)
#  |
#  |      Parameters
#  |      ----------
#  |      pluginPath: std::string const &
#  |      functionName: std::string const &
#  |
#  |      setComputeJacobianDotXGFunction(self, newPtr)
#  |
#  |      Parameters
#  |      ----------
#  |      newPtr: FPtr6
#  |
#  |  setComputeJacobianXGFunction(self, *args)
#  |      setComputeJacobianXGFunction(self, pluginPath, functionName)
#  |
#  |      Parameters
#  |      ----------
#  |      pluginPath: std::string const &
#  |      functionName: std::string const &
#  |
#  |      setComputeJacobianXGFunction(self, newPtr)
#  |
#  |      Parameters
#  |      ----------
#  |      newPtr: FPtr6
#  |
#  |  setComputegFunction(self, *args)
#  |      setComputegFunction(self, pluginPath, functionName)
#  |
#  |      Parameters
#  |      ----------
#  |      pluginPath: std::string const &
#  |      functionName: std::string const &
#  |
#  |      setComputegFunction(self, fct)
#  |
#  |      Parameters
#  |      ----------
#  |      fct: FPtr6
#  |
#  |  setJacobianRhsx(self, newValue)
#  |      setJacobianRhsx(self, newValue)
#  |
#  |      Parameters
#  |      ----------
#  |      newValue: SiconosMatrix const &
#  |
#  |  setJacobianRhsxPtr(self, newPtr)
#  |      setJacobianRhsxPtr(self, newPtr)
#  |
#  |      Parameters
#  |      ----------
#  |      newPtr: SP::SiconosMatrix
#  |
#  |  setN(self, newN)
#  |      setN(self, newN)
#  |
#  |      Parameters
#  |      ----------
#  |      newN: unsigned int
#  |
#  |  setNumber(self, new_number)
#  |      setNumber(self, new_number) -> int
#  |
#  |      Parameters
#  |      ----------
#  |      new_number: int
#  |
#  |  setR(self, newValue)
#  |      setR(self, newValue)
#  |
#  |      Parameters
#  |      ----------
#  |      newValue: SiconosVector const &
#  |
#  |  setRPtr(self, newPtr)
#  |      setRPtr(self, newPtr)
#  |
#  |      Parameters
#  |      ----------
#  |      newPtr: SP::SiconosVector
#  |
#  |  setRhs(self, newValue)
#  |      setRhs(self, newValue)
#  |
#  |      Parameters
#  |      ----------
#  |      newValue: SiconosVector const &
#  |
#  |  setRhsPtr(self, newPtr)
#  |      setRhsPtr(self, newPtr)
#  |
#  |      Parameters
#  |      ----------
#  |      newPtr: SP::SiconosVector
#  |
#  |  setStepsInMemory(self, steps)
#  |      setStepsInMemory(self, steps)
#  |
#  |      Parameters
#  |      ----------
#  |      steps: int
#  |
#  |  setWorkVector(self, newVect)
#  |      setWorkVector(self, newVect)
#  |
#  |      Parameters
#  |      ----------
#  |      newVect: VectorOfVectors const &
#  |
#  |  setX(self, newValue)
#  |      setX(self, newValue)
#  |
#  |      Parameters
#  |      ----------
#  |      newValue: SiconosVector const &
#  |
#  |  setX0(self, newValue)
#  |      setX0(self, newValue)
#  |
#  |      Parameters
#  |      ----------
#  |      newValue: SiconosVector const &
#  |
#  |  setX0Ptr(self, newPtr)
#  |      setX0Ptr(self, newPtr)
#  |
#  |      Parameters
#  |      ----------
#  |      newPtr: SP::SiconosVector
#  |
#  |  setXPtr(self, newPtr)
#  |      setXPtr(self, newPtr)
#  |
#  |      Parameters
#  |      ----------
#  |      newPtr: SP::SiconosVector
#  |
#  |  setz(self, newValue)
#  |      setz(self, newValue)
#  |
#  |      Parameters
#  |      ----------
#  |      newValue: SiconosVector const &
#  |
#  |  setzPtr(self, newPtr)
#  |      setzPtr(self, newPtr)
#  |
#  |      Parameters
#  |      ----------
#  |      newPtr: SP::SiconosVector
#  |
#  |  stepsInMemory(self)
#  |      stepsInMemory(self) -> int
#  |
#  |      Parameters
#  |      ----------
#  |      self: DynamicalSystem const *
#  |
#  |  subWorkVector(self, newVal, id)
#  |      subWorkVector(self, newVal, id)
#  |
#  |      Parameters
#  |      ----------
#  |      newVal: SP::SiconosVector
#  |      id: DynamicalSystem::WorkNames const &
#  |
#  |  update(self, time)
#  |      update(self, time)
#  |
#  |      Parameters
#  |      ----------
#  |      time: double
#  |
#  |  updatePlugins(self, time)
#  |      updatePlugins(self, time)
#  |
#  |      Parameters
#  |      ----------
#  |      time: double
#  |
#  |  workspace(self, *args)
#  |      workspace(self) -> VectorOfVectors
#  |      workspace(self, id) -> SP::SiconosVector
#  |
#  |      Parameters
#  |      ----------
#  |      id: DynamicalSystem::WorkNames const &
#  |
#  |  x(self)
#  |      x(self) -> SP::SiconosVector
#  |
#  |      Parameters
#  |      ----------
#  |      self: DynamicalSystem const *
#  |
#  |  x0(self)
#  |      x0(self) -> SP::SiconosVector
#  |
#  |      Parameters
#  |      ----------
#  |      self: DynamicalSystem const *
#  |
#  |  xMemory(self)
#  |      xMemory(self) -> SP::SiconosMemory
#  |
#  |      Parameters
#  |      ----------
#  |      self: DynamicalSystem const *
#  |
#  |  z(self)
#  |      z(self) -> SP::SiconosVector
#  |
#  |      Parameters
#  |      ----------
#  |      self: DynamicalSystem const *
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods inherited from siconos.kernel.DynamicalSystem:
#  |
#  |  resetCount(new_count=0)
#  |      resetCount(new_count=0) -> int
#  |
#  |      Parameters
#  |      ----------
#  |      new_count: int
#  |
#  |      resetCount() -> int
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from siconos.kernel.DynamicalSystem:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from siconos.kernel.DynamicalSystem:
#  |
#  |  acce_like = 5
#  |
#  |  acce_memory = 4
#  |
#  |  free = 2
#  |
#  |  free_tdg = 6
#  |
#  |  freeresidu = 1
#  |
#  |  local_buffer = 0
#  |
#  |  qtmp = 3
#  |
#  |  sizeWorkV = 7

# %% [markdown]
# ## Nonsmooth laws and constraints : the interaction(s) between dynamical systems
#
# Now, the nonsmooth part of the system must be defined, namely what are the nonsmooth laws and constraints between the variables. In Siconos, the definition of a nonsmooth law and a relation between one or two dynamical systems is called an Interaction (see Interactions between dynamical systems). Thus, the definition of a set of dynamical systems and of interactions between them will lead to the complete nonsmooth dynamical system.
#
# Clearly, the constraint here must state that the ball must stay above the ground, and when it hits the ground, a reaction force appears. Thus, as a local variables of the Interaction, we introduce $y$ as the distance between the ball and the floor and $\lambda$ as the multiplier that corresponds to the reaction at contact.
# The constraint writes:
#
# $$y(t) = q(t) - R - ground\_position$$
#
# in Siconos, this corresponds to a **LagrangianLinearTIR** (TIR stands for time-invariant relation), written as
#
# $$
# \begin{array}{ccc}
# y &=& Hq + b\\
# p &=& H^t \lambda
# \end{array}, \ \ \ \ H = [1 \ 0 \ 0], b = [ground\_position]
# $$

# %%
# ball-floor
H = np.zeros((1, 3))
H[0, 0] = 1.
# b = ground position
ground_position = [0.5]
relation = sk.LagrangianLinearTIR(H)

# %% [markdown]
# The behavior at impact must be defined. We introduce a restitutive coefficient $e$ such that
#
# $$\textrm{if} \ y=0, \ \dot y(t^+) = -e \dot y(t^-)$$
# $t^+$ and $t^-$ being post and pre-impact times.
#
# At impact, the unilateral constraint is such that
#
# $$0 \leq y \perp \lambda \geq 0$$
# which simply states that when the ball is not in contact, the reaction is null and the distance to the ground is positive while when the ball touch the ground, the reaction must be positive.
#
# This relation and the pre-post velocity relation are defined with a **NewtonImpactNSL**

# %%
e = 0.9
nonsmooth_law = sk.NewtonImpactNSL(e)

# %% [markdown]
# A nonsmooth law and a relation define something called **Interaction** in Siconos

# %%
interaction = sk.Interaction(nonsmooth_law, relation)

# %% [markdown]
# Notice that this interaction just describe some relations and laws but is not connected to any real dynamical system, for the moment.
#
# The modeling part is almost complete, since only one dynamical system and one interaction are needed to describe the problem.
# They must be gathered into a specific object, the **Model**.
# A model contains a nonsmooth dynamical system and the description of its simulation. The building of this object is quite simple: just set the time window for the simulation, include dynamical systems and link them to the correct interactions.
#
#                       NSDS == a set of Dynamical Systems + a set of Interactions

# %%
# dynamical systems and interactions must be gathered into a model, defined on a time interval
t0 = 0. # initial time
T = 10. # duration of the simulation
BouncingBall = sk.Model(t0, T)
# 1 - add the dynamical system in the nonsmooth dynamical system of the model
BouncingBall.nonSmoothDynamicalSystem().insertDynamicalSystem(ball)
# 2 - link the interaction and the dynamical system
BouncingBall.nonSmoothDynamicalSystem().link(interaction, ball)

# %% [markdown]
# # Part 2 - Simulation process definition
#
# It's time to describe how our nonsmooth dynamical system will be discretize, formulate and solve.
# You need now to define how the nonsmooth dynamical system will be integrated over time. This is the role of the **Simulation**, which must set:
#
# * how dynamical systems are discretized and integrate over a time step
# * how the resulting nonsmooth problem(s) will be formalized and solved
#
# Two different strategies are available : event-capturing (a.k.a time stepping) schemes and event-driven schemes.
#
# For this example, an event-capturing strategy will be used, with a Moreau-Jean integrator and a LCP (Linear Complementarity Problem) formulation.
#
# Let us start with the 'one-step integrator', i.e. the description of the discretisation and integration of the dynamics over a time step, between time $t_i$ and $t_{i+1}$. The integration of the dynamics over the time step is based on a $\theta$-method, and the time-discretisation leads to:
#
# $$
# \begin{array}{ccc}
#     \dot y_{k+1} &=& Hv^{free}_{k}  +  HM^{-1}H^t\lambda_{k+1} \\
#     v^{free}_k &=&  v_k + M^{-1}hF_{ext,k+\theta}\\
#     if \bar y_{k,\gamma} \leq 0 \ &then& \ 0 \leq \dot y_{k+1} \perp \lambda_{k+1} \geq 0
#   \end{array}
# $$
#
# which turns to be a Linear Complementarity System.
#
# The time-discretisation and the LCP are implemented as:

# %%
theta = 0.5
osi = sk.LsodarOSI()
osnspb_impact = sk.LCP()
osnspb_acc = sk.LCP()

# %% [markdown]
# Depending on the chosen formulation, different solvers are available. You can for example change the default (Lemke)
# for a non-symmetric QP, as below.
# A complete list of available solvers can be found in documentation (LCP solvers: http://siconos.gforge.inria.fr/users_guide/lcp_solvers.html#lcp-solvers).

# %% [markdown]
# Then the last step consists in the simulation creation, with its time discretisation

# %%
# simulation and time discretisation
time_step =  0.005
td = sk.TimeDiscretisation(t0, time_step)
simu = sk.EventDriven(td)
simu.insertIntegrator(osi)
simu.insertNonSmoothProblem(osnspb_impact, sk.SICONOS_OSNSP_ED_IMPACT)
simu.insertNonSmoothProblem(osnspb_acc, sk.SICONOS_OSNSP_ED_SMOOTH_ACC)

# %% [markdown]
# The connection with the nonsmooth dynamical system is done through the **Model**

# %%
BouncingBall.setSimulation(simu)
BouncingBall.initialize()

# %% [markdown]
# The model is now complete and ready to run
#
# ## Leading the simulation process
#
# For the present case, x,y and λ at each time step are needed for postprocessing. Here is an example on how to get and save them in a numpy array

# %%
N = int((T - t0) / simu.timeStep()) + 1
# numpy array used to save data at each time step, for post-processing
data_plot = np.zeros((2 * N, 9))

lamb1 = interaction.lambda_(1)
lamb2 = interaction.lambda_(2)

q = ball.q()
v = ball.velocity()
p = ball.p(1)
f = ball.p(2)

k = 0
kns = 0 # number of nonsmooth events 
# initial state
data_plot[k, 0] = t0
data_plot[k, 1] = q[0]
data_plot[k, 2] = v[0]
data_plot[k, 3] = p[0]
data_plot[k, 4] = f[0]

def compute_energy(v, z):
    return 0.5 * np.dot(v, np.dot(mass, v)), m * g * z

data_plot[k, 7:] = compute_energy(v, q[0])

k += 1
non_smooth = False
em = simu.eventsManager()
while simu.hasNextEvent():
    simu.advanceToEvent() # Build and solve the LCPs
    
    if em.nextEvent().getType() == 2:
        non_smooth = True
    simu.processEvents() # Save current state and prepare next step
            
    #If the treated event is non smooth, the pre-impact state
    # has been solved in memory vectors during process.
    if non_smooth:
        data_plot[k, 0] = simu.startingTime()
        data_plot[k, 1] = ball.qMemory().getSiconosVector(1)[0]
        data_plot[k, 2] = ball.velocityMemory().getSiconosVector(1)[0]
        data_plot[k, 3] = p[0]
        data_plot[k, 4] = f[0]
        k += 1
        kns += 1
        non_smooth = False

    data_plot[k, 0] = simu.startingTime()
    data_plot[k, 1] = q[0]
    data_plot[k, 2] = v[0]
    data_plot[k, 3] = p[0]
    data_plot[k, 4] = f[0]
    data_plot[k, 5] = lamb1[0]
    data_plot[k, 6] = lamb2[0]
    data_plot[k, 7:] = compute_energy(v, q[0])
    k += 1

# %% [markdown]
# * *hasNextEvent()* is true as long as there are events to be considered, i.e. until T is reached
# * *nextStep()* is mainly used to increment the time step, save current state and prepare initial values for next step.
# * *computeOneStep()* performs computation over the current time step. In the Moreau's time stepping case, it will first integrate the dynamics to
#   obtain the so-called free-state, that is without non-smooth effects, then it will formalize and solve a LCP before re-integrate the dynamics using the LCP results.
#
# The results can now be postprocessed, using matplotlib pyplot for example

# %%
import matplotlib.pyplot as plt
# %matplotlib inline  
fig_size = [14, 6]
plt.rcParams["figure.figsize"] = fig_size
time = data_plot[:, 0]
#plt.subplot(411)
#plt.title('position')
plt.plot(time, data_plot[:, 1], label='position')
plt.plot(time, data_plot[:, 2], label='velocity')
plt.grid()
plt.legend()

# %%
plt.subplot(121)
plt.plot(time, data_plot[:, 5])
plt.title('reaction impulse')
plt.subplot(122)
plt.xlim(8,10)
plt.ylim(0,0.2)
plt.plot(time, data_plot[:, 5])

# %%
Ec = data_plot[:, 7]
Ep = data_plot[:, 8]
plt.plot(time, Ec, label='Ec')
plt.plot(time, Ep, label='Ep')
plt.plot(time, Ec + Ep, label='Total energy')
plt.legend()
